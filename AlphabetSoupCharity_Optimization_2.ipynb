# %% [markdown]
# <a href="https://colab.research.google.com/github/amydst/Deep-Learning-Challenge/blob/main/Deep_learning_challenge.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf
import hvplot.pandas  # noqa
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='p1002'>
#   <div id="e4e6510f-1849-4057-8738-6e87ffbd5474" data-root-id="p1002" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"fef978d9-2a49-481d-9481-a08dd1a36ff3":{"version":"3.4.1","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"p1002"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"p1003","attributes":{"plot_id":"p1002","comm_id":"21c486a4fa3c43ad8c6027f6c8d7ee80","client_comm_id":"8d93fd9e7b3941e98c80d0dd9a4d13f1"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"TemplateEditor1","properties":[{"name":"layout","kind":"Any","default":[]}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"copy_to_clipboard1","properties":[{"name":"fill","kind":"A ...
#   var render_items = [{"docid":"fef978d9-2a49-481d-9481-a08dd1a36ff3","roots":{"p1002":"e4e6510f-1849-4057-8738-6e87ffbd5474"},"root_ids":["p1002"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>

# %%
#  Import and read the charity_data.csv.
import pandas as pd
application_df = pd.read_csv("https://static.bc-edx.com/data/dl-1-2/m21/lms/starter/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0              0                      N     5000              1
# 1         1-9999                      N   108590              1
# 2              0                      N     5000              0
# 3    10000-24999                      N     6692              1
# 4  100000-499999                      N   142590              1

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.

application_df.drop(columns=['EIN','NAME'],inplace= True)

application_df.head(5)
# Out:
#   APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0              T10       Independent          C1000    ProductDev
# 1               T3       Independent          C2000  Preservation
# 2               T5  CompanySponsored          C3000    ProductDev
# 3               T3  CompanySponsored          C2000  Preservation
# 4               T3       Independent          C1000     Heathcare
#
#    ORGANIZATION  STATUS     INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  \
# 0   Association       1              0                      N     5000
# 1  Co-operative       1         1-9999                      N   108590
# 2   Association       1              0                      N     5000
# 3         Trust       1    10000-24999                      N     6692
# 4         Trust       1  100000-499999                      N   142590
#
#    IS_SUCCESSFUL
# 0              1
# 1              1
# 2              0
# 3              1
# 4              1

# %%
# Determine the number of unique values in each column.
application_df.nunique()
# Out:
# APPLICATION_TYPE            17
# AFFILIATION                  6
# CLASSIFICATION              71
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts to identify and replace with "Other"
application_counts = application_df['APPLICATION_TYPE'].value_counts()

application_counts
# Out:
# APPLICATION_TYPE
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: count, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`

application_types_to_replace = application_counts[application_counts <= 10].index.tolist()

# %%
# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure replacement was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# APPLICATION_TYPE
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# T9         156
# T13         66
# T12         27
# T2          16
# Other       11
# Name: count, dtype: int64

# %%
# Look at CLASSIFICATION value counts to identify and replace with "Other"
classification_counts = application_df['CLASSIFICATION'].value_counts()

classification_counts
# Out:
# CLASSIFICATION
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C4120        1
# C8210        1
# C2561        1
# C4500        1
# C2150        1
# Name: count, Length: 71, dtype: int64

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1

classification_counts[classification_counts > 1]
# Out:
# CLASSIFICATION
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C7200       32
# C2300       32
# C1240       30
# C8000       20
# C7120       18
# C1500       16
# C1800       15
# C6000       15
# C1250       14
# C8200       11
# C1238       10
# C1278       10
# C1235        9
# C1237        9
# C7210        7
# C2400        6
# C1720        6
# C4100        6
# C1257        5
# C1600        5
# C1260        3
# C2710        3
# C0           3
# C3200        2
# C1234        2
# C1246        2
# C1267        2
# C1256        2
# Name: count, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
classifications_to_replace = classification_counts[classification_counts < 100].index.tolist()

# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")

# Check to make sure replacement was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# CLASSIFICATION
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# Other      669
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# Name: count, dtype: int64

# %%
pd.set_option('display.float_format', lambda x: '{:,.2f}'.format(x))
application_df['ASK_AMT'].describe()
# Out:
# count          34,299.00
# mean        2,769,198.68
# std        87,130,452.44
# min             5,000.00
# 25%             5,000.00
# 50%             5,000.00
# 75%             7,742.00
# max     8,597,806,340.00
# Name: ASK_AMT, dtype: float64

# %%
application_df = application_df.sort_values(by='ASK_AMT')
application_df.tail(25)
# Out:
#       APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 20103               T3  CompanySponsored          C1200  Preservation
# 24101               T3       Independent          C2000  Preservation
# 11126               T3  CompanySponsored          C1000  Preservation
# 24799               T3       Independent          C1000     Heathcare
# 33718               T3       Independent          C1000     Heathcare
# 33717               T3  CompanySponsored          C1200     Heathcare
# 26098               T3       Independent          C1000     Heathcare
# 33810               T3     Family/Parent          C1000  Preservation
# 21558               T3       Independent          C1000  Preservation
# 32944               T3       Independent          C2000  Preservation
# 30121               T3       Independent          C1000     Heathcare
# 871                 T3       Independent          C1000  Preservation
# 25563               T3       Independent          C1000  Preservation
# 24796               T3       Independent          C2000  Preservation
# 12344               T3       Independent          C1700     Heathcare
# 33256               T3       Independent          C2000  Preservation
# 773                 T3     Family/Parent          Other  Preservation
# 33027               T3       Independent          C2000  Preservation
# 21633               T3       Independent          C1000     Heathcare
# 24947               T3       Independent          C1000     Heathcare
# 31337               T3  CompanySponsored          C1000  Preservation
# 24795               T3       Independent          C2000  Preservation
# 33678               T3       Independent          C1200     Heathcare
# 34222               T3       Independent          C2000  Preservation
# 33175               T3       Independent          C1000     Heathcare
#
#        ORGANIZATION  STATUS INCOME_AMT SPECIAL_CONSIDERATIONS     ASK_AMT  \
# 20103   Association       1       50M+                      N   888279151
# 24101         Trust       1       50M+                      N   910629836
# 11126         Trust       1       50M+                      N   912100264
# 24799         Trust       1       50M+                      N   923741684
# 33718         Trust       1       50M+                      N   938554501
# 33717         Trust       1       50M+                      N   967076877
# 26098         Trust       1       50M+                      N   988114720
# 33810         Trust       1       50M+                      N  1011585213
# 21558   Association       1       50M+                      N  1068119241
# 32944         Trust       1       50M+                      N  1128874990
# 30121         Trust       1       50M+                      N  1281905997
# 871           Trust       1       50M+                      N  1326447551
# 25563         Trust       1       50M+                      N  1382280715
# 24796         Trust       1       50M+                      N  1391441555
# 12344         Trust       1       50M+                      N  1420537175
# 33256         Trust       1       50M+                      N  1665460552
# 773           Trust       1       50M+                      N  1736232349
# 33027         Trust       1       50M+                      N  1893400128
# 21633         Trust       1       50M+                      N  2264109450
# 24947         Trust       1       50M+                      N  2310256039
# 31337         Trust       1       50M+                      N  3391919220
# 24795         Trust       1       50M+                      N  4653011914
# 33678         Trust       1       50M+                      N  5591584994
# 34222  Co-operative       1       50M+                      N  8556638692
# 33175         Trust       1       50M+                      N  8597806340
#
#        IS_SUCCESSFUL
# 20103              0
# 24101              0
# 11126              0
# 24799              0
# 33718              1
# 33717              0
# 26098              1
# 33810              0
# 21558              0
# 32944              0
# 30121              1
# 871                0
# 25563              0
# 24796              0
# 12344              0
# 33256              0
# 773                1
# 33027              0
# 21633              0
# 24947              1
# 31337              1
# 24795              0
# 33678              0
# 34222              0
# 33175              1

# %%
application_df.hvplot.scatter(x='index', 
                          y='ASK_AMT',
                          width=1000,
                          hover_cols=['ASK_AMT', 'index']
                          )
# Out:
# :Scatter   [index]   (ASK_AMT)

# %%
# bins = [0,5000,10000,30000,50000,70000,90000,9000000000]

# # bin_labels = ['0-5,000','5,001-10,000','10,001-30,000','30,001-50000','50001-70000','70001-90000', 'over 90,000']
# application_df['ASK_AMT_BINS'] = pd.cut(application_df['ASK_AMT'],bin_edges,labels=bin_labels)

# application_df

# %%
# # Define the bin edges
# bin_edges = [
#     0,
#     5000,
#     450000,
#     900000,
#     1350000,
#     1800000,
#     2250000,
#     2700000,
#     3150000,
#     3600000,
#     4050000,
#     4500000,
#     4950000,
#     5400000,
#     5850000,
#     6300000,
#     6750000,
#     7200000,
#     7650000,
#     8100000,
#     8550000,
#     9000000
# ]

# # Define the bin labels
# bin_labels = [
#     "0 - 5,000",
#     "5,001 - 450,000",
#     "450,001 - 900,000",
#     "900,001 - 1,350,000",
#     "1,350,001 - 1,800,000",
#     "1,800,001 - 2,250,000",
#     "2,250,001 - 2,700,000",
#     "2,700,001 - 3,150,000",
#     "3,150,001 - 3,600,000",
#     "3,600,001 - 4,050,000",
#     "4,050,001 - 4,500,000",
#     "4,500,001 - 4,950,000",
#     "4,950,001 - 5,400,000",
#     "5,400,001 - 5,850,000",
#     "5,850,001 - 6,300,000",
#     "6,300,001 - 6,750,000",
#     "6,750,001 - 7,200,000",
#     "7,200,001 - 7,650,000",
#     "7,650,001 - 8,100,000",
#     "8,100,001 - 8,550,000",
#     "over 8,550,000 "
# ]

# # Create the bins in the DataFrame
# application_df['ASK_AMT_BINS'] = pd.cut(application_df['ASK_AMT'], bins=bin_edges, labels=bin_labels)

# %%
# ask_amt_counts = application_df['ASK_AMT_BINS'].value_counts()
# ask_amt_counts

# %%
application_cat = application_df.copy()

application_cat.drop('ASK_AMT',axis=1,inplace =True)

# %%
# Convert categorical data to numeric with `pd.get_dummies`

# application_converted = pd.get_dummies(data=application_cat, columns=['APPLICATION_TYPE', 'INCOME_AMT','AFFILIATION', 'CLASSIFICATION', 'USE_CASE','ORGANIZATION', 'SPECIAL_CONSIDERATIONS','ASK_AMT_BINS'],dtype=int)
application_converted = pd.get_dummies(data=application_cat, columns=['APPLICATION_TYPE', 'INCOME_AMT','AFFILIATION', 
                                                                      'CLASSIFICATION', 'USE_CASE','ORGANIZATION', 'SPECIAL_CONSIDERATIONS'],dtype=int)

application_converted.drop('SPECIAL_CONSIDERATIONS_N',axis=1,inplace =True)

application_converted.drop('STATUS',axis=1,inplace =True)

application_converted
# Out:
#        IS_SUCCESSFUL  APPLICATION_TYPE_Other  APPLICATION_TYPE_T10  \
# 0                  1                       0                     1
# 20358              0                       0                     0
# 20356              1                       0                     0
# 20355              1                       0                     0
# 20354              0                       0                     0
# ...              ...                     ...                   ...
# 31337              1                       0                     0
# 24795              0                       0                     0
# 33678              0                       0                     0
# 34222              0                       0                     0
# 33175              1                       0                     0
#
#        APPLICATION_TYPE_T12  APPLICATION_TYPE_T13  APPLICATION_TYPE_T19  \
# 0                         0                     0                     0
# 20358                     0                     0                     0
# 20356                     0                     0                     0
# 20355                     0                     0                     0
# 20354                     0                     0                     0
# ...                     ...                   ...                   ...
# 31337                     0                     0                     0
# 24795                     0                     0                     0
# 33678                     0                     0                     0
# 34222                     0                     0                     0
# 33175                     0                     0                     0
#
#        APPLICATION_TYPE_T2  APPLICATION_TYPE_T3  APPLICATION_TYPE_T4  \
# 0                        0                    0                    0
# 20358                    0                    0                    0
# 20356                    0                    0                    0
# 20355                    0                    1                    0
# 20354                    0                    1                    0
# ...                    ...                  ...                  ...
# 31337                    0                    1                    0
# 24795                    0                    1                    0
# 33678                    0                    1                    0
# 34222                    0                    1                    0
# 33175                    0                    1                    0
#
#        APPLICATION_TYPE_T5  ...  USE_CASE_CommunityServ  USE_CASE_Heathcare  \
# 0                        0  ...                       0                   0
# 20358                    1  ...                       0                   0
# 20356                    0  ...                       0                   0
# 20355                    0  ...                       0                   0
# 20354                    0  ...                       0                   0
# ...                    ...  ...                     ...                 ...
# 31337                    0  ...                       0                   0
# 24795                    0  ...                       0                   0
# 33678                    0  ...                       0                   1
# 34222                    0  ...                       0                   0
# 33175                    0  ...                       0                   1
#
#        USE_CASE_Other  USE_CASE_Preservation  USE_CASE_ProductDev  \
# 0                   0                      0                    1
# 20358               0                      0                    1
# 20356               0                      0                    1
# 20355               0                      1                    0
# 20354               0                      1                    0
# ...               ...                    ...                  ...
# 31337               0                      1                    0
# 24795               0                      1                    0
# 33678               0                      0                    0
# 34222               0                      1                    0
# 33175               0                      0                    0
#
#        ORGANIZATION_Association  ORGANIZATION_Co-operative  \
# 0                             1                          0
# 20358                         1                          0
# 20356                         1                          0
# 20355                         0                          0
# 20354                         1                          0
# ...                         ...                        ...
# 31337                         0                          0
# 24795                         0                          0
# 33678                         0                          0
# 34222                         0                          1
# 33175                         0                          0
#
#        ORGANIZATION_Corporation  ORGANIZATION_Trust  SPECIAL_CONSIDERATIONS_Y
# 0                             0                   0                         0
# 20358                         0                   0                         0
# 20356                         0                   0                         0
# 20355                         0                   1                         0
# 20354                         0                   0                         0
# ...                         ...                 ...                       ...
# 31337                         0                   1                         0
# 24795                         0                   1                         0
# 33678                         0                   1                         0
# 34222                         0                   0                         0
# 33175                         0                   1                         0
#
# [34299 rows x 51 columns]

# %%
# Split our preprocessed data into our features and target arrays
y = application_converted['IS_SUCCESSFUL'].values

X = application_converted.drop(columns=['IS_SUCCESSFUL']).values

# %%
# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y)

# %%
print(X_train.shape)
# Out:
# (25724, 50)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
number_input_features = len(X_train[0])
hidden_nodes_layer1 =  32
hidden_nodes_layer2 = 16
hidden_nodes_layer3 = 8
nn = tf.keras.models.Sequential()

# First hidden layer
dense1 = tf.keras.layers.Dense(units=hidden_nodes_layer1, activation="tanh",input_dim=number_input_features)
nn.add(dense1)

# Second hidden layer
dense2 = tf.keras.layers.Dense(units=hidden_nodes_layer2, activation="tanh")
nn.add(dense2)

# Third hidden layer
dense3 = tf.keras.layers.Dense(units=hidden_nodes_layer3, activation="tanh")

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_12 (Dense)            (None, 32)                1632
#
#  dense_13 (Dense)            (None, 16)                528
#
#  dense_15 (Dense)            (None, 1)                 17
#
# =================================================================
# Total params: 2,177
# Trainable params: 2,177
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
fit_model = nn.fit(X_train_scaled,y_train,epochs=125)
# Out:
# Epoch 1/125
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5781 - accuracy: 0.7152
# Epoch 2/125
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5569 - accuracy: 0.7276
# Epoch 3/125
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5528 - accuracy: 0.7289
# Epoch 4/125
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5504 - accuracy: 0.7301
# Epoch 5/125
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5486 - accuracy: 0.7296
# Epoch 6/125
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5471 - accuracy: 0.7318
# Epoch 7/125
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5464 - accuracy: 0.7317
# Epoch 8/125
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5455 - accuracy: 0.7324
# Epoch 9/125
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5446 - accuracy: 0.7327
# Epoch 10/125
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5442 - accuracy: 0.7338
# Epoch 11/125
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5434 - accuracy: 0.7327
# Epoch 12/125
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5432 - accuracy: 0.7343
# Epoch 13/125
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5426 - accuracy: 0.7340
# Epoch 14/125
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5421 - accuracy: 0.7335
# Epoch 15/125
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5417 - accuracy: 0.7350
# Epoch 16/125
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5414 - accuracy: 0.7348
# Epoch 17/125
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5408 - accuracy: 0.7347
# Epoch 18/125
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5407 - accuracy: 0.7356
# Epoch 19/125
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5405 - accuracy: 0.7360
# Epoch 20/125
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5396 - accuracy: 0.7355
# Epoch 21/125
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5398 - accuracy: 0.7359
# Epoch 22/125
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5396 - accuracy: 0.7361
# Epoch 23/125
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5393 - accuracy: 0.7370
# Epoch 24/125
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5392 - accuracy: 0.7368
# Epoch 25/125
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5389 - accuracy: 0.7370
# Epoch 26/125
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5385 - accuracy: 0.7370
# Epoch 27/125
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5381 - accuracy: 0.7371
# Epoch 28/125
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5381 - accuracy: 0.7368
# Epoch 29/125
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5381 - accuracy: 0.7380
# Epoch 30/125
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5378 - accuracy: 0.7372
# Epoch 31/125
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5375 - accuracy: 0.7370
# Epoch 32/125
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5374 - accuracy: 0.7365
# Epoch 33/125
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5374 - accuracy: 0.7377
# Epoch 34/125
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5370 - accuracy: 0.7375
# Epoch 35/125
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5367 - accuracy: 0.7376
# Epoch 36/125
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5367 - accuracy: 0.7376
# Epoch 37/125
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5364 - accuracy: 0.7378
# Epoch 38/125
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5366 - accuracy: 0.7375
# Epoch 39/125
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5363 - accuracy: 0.7368
# Epoch 40/125
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5363 - accuracy: 0.7381
# Epoch 41/125
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5363 - accuracy: 0.7379
# Epoch 42/125
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5359 - accuracy: 0.7392
# Epoch 43/125
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5356 - accuracy: 0.7385
# Epoch 44/125
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5357 - accuracy: 0.7385
# Epoch 45/125
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5354 - accuracy: 0.7378
# Epoch 46/125
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5355 - accuracy: 0.7391
# Epoch 47/125
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5354 - accuracy: 0.7388
# Epoch 48/125
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5352 - accuracy: 0.7388
# Epoch 49/125
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5352 - accuracy: 0.7383
# Epoch 50/125
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5353 - accuracy: 0.7388
# Epoch 51/125
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5350 - accuracy: 0.7391
# Epoch 52/125
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5347 - accuracy: 0.7378
# Epoch 53/125
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5351 - accuracy: 0.7393
# Epoch 54/125
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5346 - accuracy: 0.7394
# Epoch 55/125
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5344 - accuracy: 0.7388
# Epoch 56/125
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5348 - accuracy: 0.7392
# Epoch 57/125
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5342 - accuracy: 0.7403
# Epoch 58/125
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5344 - accuracy: 0.7400
# Epoch 59/125
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5341 - accuracy: 0.7397
# Epoch 60/125
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5342 - accuracy: 0.7395
# Epoch 61/125
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5342 - accuracy: 0.7399
# Epoch 62/125
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5343 - accuracy: 0.7400
# Epoch 63/125
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5340 - accuracy: 0.7384
# Epoch 64/125
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5338 - accuracy: 0.7394
# Epoch 65/125
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5339 - accuracy: 0.7392
# Epoch 66/125
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5337 - accuracy: 0.7396
# Epoch 67/125
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5338 - accuracy: 0.7388
# Epoch 68/125
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5338 - accuracy: 0.7394
# Epoch 69/125
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5337 - accuracy: 0.7393
# Epoch 70/125
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5336 - accuracy: 0.7403
# Epoch 71/125
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5335 - accuracy: 0.7402
# Epoch 72/125
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5337 - accuracy: 0.7401
# Epoch 73/125
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5334 - accuracy: 0.7393
# Epoch 74/125
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5334 - accuracy: 0.7403
# Epoch 75/125
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5332 - accuracy: 0.7397
# Epoch 76/125
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5333 - accuracy: 0.7397
# Epoch 77/125
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5333 - accuracy: 0.7397
# Epoch 78/125
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5332 - accuracy: 0.7400
# Epoch 79/125
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5331 - accuracy: 0.7393
# Epoch 80/125
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5331 - accuracy: 0.7402
# Epoch 81/125
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5330 - accuracy: 0.7409
# Epoch 82/125
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5330 - accuracy: 0.7399
# Epoch 83/125
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5328 - accuracy: 0.7393
# Epoch 84/125
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5330 - accuracy: 0.7395
# Epoch 85/125
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5329 - accuracy: 0.7390
# Epoch 86/125
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5328 - accuracy: 0.7400
# Epoch 87/125
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5326 - accuracy: 0.7399
# Epoch 88/125
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5329 - accuracy: 0.7401
# Epoch 89/125
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5327 - accuracy: 0.7406
# Epoch 90/125
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5324 - accuracy: 0.7407
# Epoch 91/125
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5328 - accuracy: 0.7406
# Epoch 92/125
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5324 - accuracy: 0.7402
# Epoch 93/125
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5323 - accuracy: 0.7402
# Epoch 94/125
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5326 - accuracy: 0.7399
# Epoch 95/125
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5325 - accuracy: 0.7411
# Epoch 96/125
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5325 - accuracy: 0.7405
# Epoch 97/125
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5324 - accuracy: 0.7392
# Epoch 98/125
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5322 - accuracy: 0.7395
# Epoch 99/125
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5322 - accuracy: 0.7406
# Epoch 100/125
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5324 - accuracy: 0.7401
# Epoch 101/125
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5322 - accuracy: 0.7397
# Epoch 102/125
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5321 - accuracy: 0.7408
# Epoch 103/125
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5319 - accuracy: 0.7406
# Epoch 104/125
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5320 - accuracy: 0.7405
# Epoch 105/125
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5321 - accuracy: 0.7403
# Epoch 106/125
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5319 - accuracy: 0.7406
# Epoch 107/125
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5321 - accuracy: 0.7405
# Epoch 108/125
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5320 - accuracy: 0.7409
# Epoch 109/125
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5319 - accuracy: 0.7407
# Epoch 110/125
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5320 - accuracy: 0.7404
# Epoch 111/125
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5319 - accuracy: 0.7395
# Epoch 112/125
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5318 - accuracy: 0.7411
# Epoch 113/125
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5316 - accuracy: 0.7412
# Epoch 114/125
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5318 - accuracy: 0.7405
# Epoch 115/125
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5318 - accuracy: 0.7399
# Epoch 116/125
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5317 - accuracy: 0.7415
# Epoch 117/125
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5315 - accuracy: 0.7404
# Epoch 118/125
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5315 - accuracy: 0.7404
# Epoch 119/125
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5316 - accuracy: 0.7401
# Epoch 120/125
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5314 - accuracy: 0.7403
# Epoch 121/125
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5317 - accuracy: 0.7407
# Epoch 122/125
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5315 - accuracy: 0.7409
# Epoch 123/125
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5314 - accuracy: 0.7404
# Epoch 124/125
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5313 - accuracy: 0.7407
# Epoch 125/125
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5314 - accuracy: 0.7397

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.5520 - accuracy: 0.7291 - 475ms/epoch - 2ms/step
# Loss: 0.552031934261322, Accuracy: 0.7290962338447571

# %%
# Export our model to HDF5 file

nn.save('applications_optimized_2.h5')
nn.save('applications_optimized_2.keras')
